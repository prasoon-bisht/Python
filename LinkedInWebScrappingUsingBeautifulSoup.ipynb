# %% [markdown]
# #### Finding Data Analyst Jobs in Gurugram, Harayana, India.
# ##### These filter are already applied on the website.

# %%
# Import the necessary libraries
from bs4 import BeautifulSoup  # For parsing HTML
import requests  # For making HTTP requests
import pandas as pd  # For data manipulation and analysis

# %%
# Define the URL of the website to scrape
website = "https://www.linkedin.com/jobs/search?keywords=Data%20Analyst&location=Gurugram%2C%20Haryana%2C%20India&geoId=115884833&trk=public_jobs_jobs-search-bar_search-submit&position=1&pageNum=0"

# Send an HTTP request to the URL and get the response
result = requests.get(website)
content = result.text

# Parse the HTML content of the webpage using BeautifulSoup
# 'lxml' is one of the parsers supported by BeautifulSoup
soup = BeautifulSoup(content, 'lxml')

# %%
# print(soup.prettify())

# %%
# Find the <ul> element with the class 'jobs-search__results-list' in the parsed HTML content
box = soup.find('ul', class_ = 'jobs-search__results-list')

# %%
# Initializing an empty list to store the data extracted
df_data = []

# Loop through each <li> element within the <ul> element
for data in box.find_all('li'):
    
    # Extract the job title from the <h3> element with the class 'base-search-card__title'
    title = data.find('h3', class_='base-search-card__title').get_text().strip()
    
    # Extract the subtitle (if available) from the <a> element with the class 'hidden-nested-link'
    subtitle_element = data.find('a', class_='hidden-nested-link')
    if subtitle_element:
        subtitle = subtitle_element.get_text().strip()
    else:
        subtitle = 'Subtitle not found'
    
    # Extract the city/location from the <span> element with the class 'job-search-card__location'
    city = data.find('span', class_='job-search-card__location').get_text().strip()
    
    # Extract the posting time from the <time> element with the class 'job-search-card__listdate'
    time_element = data.find('time', class_='job-search-card__listdate')
    if time_element:
        time = time_element.get_text().strip()
    else:
        time = 'Time not found'
        
    # Append the extracted data to the list
    df_data.append([title, subtitle, city, time])
        
# Create a DataFrame from the collected data with appropriate column names
df = pd.DataFrame(df_data, columns=['title', 'subtitle', 'city', 'time'])

# %%
# Save the DataFrame to a CSV file named 'data_gurugram'
# Set index=False to avoid writing row indices to the CSV file
df.to_csv('data_gurugram', index=False)

# %%
# Print the df
df
# Out:
#                                                 title  \
# 0                                        Data Analyst
# 1                                        Data Analyst
# 2                                        Data Analyst
# 3                               Analyst- Data science
# 4                              Logistics Data Analyst
# 5                           Data Analytics & Strategy
# 6                  Data Analyst / Senior Data Analyst
# 7                                       Data Engineer
# 8                       Business Intelligence Analyst
# 9                              Analyst - Data Science
# 10                     Data Analysis & Interpretation
# 11  Specialist – Data Analytics & Insight - Victor...
# 12                                       Data Analyst
# 13            Analyst/Senior Analyst – Data Analytics
# 14            Analyst/Senior Analyst – Data Analytics
# 15                                Senior Data Analyst
# 16     Data Delivery Analyst (Python,SQL) - Periscope
# 17                              Data Analyst-Gurugram
# 18                                    Power BI Expert
# 19                                       Data Analyst
# 20          Business Analyst - Data Analyst-ANA008478
# 21  Data Engineer-Gurgaon/Pune/Bangalore/Noida-Imm...
# 22                                   Big Data Analyst
# 23                               Data Quality Analyst
# 24                Analyst-Data Analytics [SQL/Python]
# 25                             BI Analyst - Team Lead
# 26       Lead Data Engineer / Principal Data Engineer
# 27                                Senior Data Analyst
# 28           Assistant Manager–Data Analyst-ANA010462
# 29           Assistant Manager–Data Analyst-ANA010452
# 30                                Senior Data Analyst
# 31           Assistant Manager–Data Analyst-ANA010468
# 32         Assistant Manager : Data Analyst-ANA010443
# 33           Assistant Manager–Data Analyst-ANA010448
# 34  Consulting Analyst, Growth Analytics - Gurugra...
# 35                                     Data Dashboard
# 36  Interesting Job Opportunity: Data Analyst - SQ...
# 37                                      Data Engineer
# 38                                      Data Engineer
# 39           Assistant Manager–Data Analyst-ANA010475
# 40                                       Data Modeler
# 41   Senior Data Engineer I / Senior Data Engineer II
# 42                                       Data Analyst
# 43                          Analyst, Data & Analytics
# 44                                     Sr. BI Analyst
# 45                              Asst Dir-Data Analyst
# 46              Consultant - Data Analytics-CPG047857
# 47                            Business System Analyst
# 48                    Analyst - Business Intelligence
# 49                                      Data Engineer
# 50                                       Data Analyst
# 51     BI Manager (Power BI) - Immediate joiners only
# 52                                    Lead BI Analyst
# 53                                      SQL Developer
# 54  Data Engineer_3+ years_ immediate hiring_ Loca...
# 55                 Manager - Data Analytics-COR027694
# 56                                      Data Engineer
# 57   Senior Analyst - Competitive intelligence Pharma
# 58                                      Data Engineer
# 59     Perf. Media Analytics - Sr Analyst - Analytics
#
#                                              subtitle  \
# 0                                                 EXL
# 1                                          Concentrix
# 2                                        Ticketmaster
# 3                                    American Express
# 4                                            Circle K
# 5                                Airtel Payments Bank
# 6                                       Urban Company
# 7                                               Nykaa
# 8                                          Concentrix
# 9                                     United Airlines
# 10                                            PURVIEW
# 11                                     Marsh McLennan
# 12                                      Acme Services
# 13                   D. E. Shaw India Private Limited
# 14                   D. E. Shaw India Private Limited
# 15                                TELUS International
# 16                                 McKinsey & Company
# 17                       Talent Socio(We're Hiring!!)
# 18                                                EXL
# 19                                            Targray
# 20                                            Genpact
# 21                                                EXL
# 22                                  AI Staffing Ninja
# 23                                              Xebia
# 24                myGwork - LGBTQ+ Business Community
# 25                                       EPAM Systems
# 26                                         MakeMyTrip
# 27                                  Home Credit India
# 28                                            Genpact
# 29                                            Genpact
# 30                                      Zypp Electric
# 31                                            Genpact
# 32                                            Genpact
# 33                                            Genpact
# 34                                   Frost & Sullivan
# 35  Kezan Consulting- A Unit of Kezan India Privat...
# 36            Techno-Comp Computer Services Pvt. Ltd.
# 37                                                EXL
# 38                                                EXL
# 39                                            Genpact
# 40                                            Coforge
# 41                                         MakeMyTrip
# 42                                 Subtitle not found
# 43                                            Stryker
# 44                                       EPAM Systems
# 45                                Moody's Corporation
# 46                                            Genpact
# 47                                           Sun Life
# 48                                    United Airlines
# 49                      RSA India (An Intact Company)
# 50                                Alp Consulting Ltd.
# 51                                         Concentrix
# 52                                       EPAM Systems
# 53                                     TekFocus Minds
# 54                                                EXL
# 55                                            Genpact
# 56                                      Battery Smart
